# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])

# %%
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16],'ro')

# %%
plt.show()

# %%
plt.axis([0,5,0,20])
plt.title('My first plot')
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.show()

# %%
import math
import numpy as np

# %%
t=np.arange(0,2.5,0.1)
y1=map(math.sin,math.pi*t)
y2=map(math.sin,math.pi*t+math.pi/2)
y3=map(math.sin,math.pi*t-math.pi/2)

# %%
plt.plot([1,2,3,2,1,0,1,2,1,4],linewidth=2.0)

# %%
plt.show()

# %%
t=np.arange(0,5,0.1)

# %%
y1=np.sin(2*np.pi*t)
y2=np.sin(2*np.pi*t)

# %%
plt.subplot(211)
plt.plot(t,y1,'b--')
plt.subplot(212)
plt.plot(t,y2,'r')

# %%
plt.show()

# %%
plt.plot([1,2,3,2,1,0,1,2,1,1],linewidth=10.0)

# %%
plt.show()

# %%
plt.subplot(121)
plt.plot(t,y1,'b--')
plt.subplot(122)
plt.plot(t,y2,'r')

# %%
plt.show()

# %%
plt.axis([0,5,0,20])
plt.title('My first plot')
plt.xlabel('Counting')
plt.ylabel('Square values')
plt.plot([1,2,3,4],[1,4,9,16],'r--')

# %%
plt.show()#xybiaoqing

# %%
plt.axis([0,5,0,20])
plt.title('My first plot',fontsize=20,fontname='SimHei',color='blue')
plt.xlabel('Counting',color='gray')
plt.ylabel('Sqiare values',color='red')
plt.text(1.05,0.95,'First')
plt.text(2,4.5,'Second')
plt.text(3,9.5,'Third')
plt.text(4,16.5,'Fourth')
plt.text(1.1,12,r'$y=x^2$',fontsize=20,bbox={'facecolor':'yellow','alpha':0.2})
plt.grid(True)
plt.plot([1,2,3,4],[0.8,3.5,8,15],'g^')
plt.plot([1,2,3,4],[1.2,4.2,10,17],'b*')
plt.legend(['First','second'],loc=2)
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.savefig('my_chart.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-235-ce24e5d42e9a> in <module>()
# ----> 1 plt.axis([0,5,0,20])
#       2 plt.title('My first plot',fontsize=20,fontname='SimHei',color='blue')
#       3 plt.xlabel('Counting',color='gray')
#       4 plt.ylabel('Sqiare values',color='red')
#       5 plt.text(1.05,0.95,'First')
#
# TypeError: 'list' object is not callable

# %%
plt.show()

# %% [markdown]
# # DateTime

# %%
import datetime

# %%
events=[datetime.date(2015,1,23),datetime.date(2015,1,28),datetime.date(2015,2,3),datetime.date(2015,2,21),datetime.date(2015,3,15)
       ,datetime.date(2015,3,24),datetime.date(2015,4,8),datetime.date(2015,4,24)]

# %%
readings=[12,22,25,20,18,15,17,14]

# %%
plt.plot(events,readings)

# %%
plt.show()

# %%
import matplotlib.dates as mdates

# %%
months=mdates.MonthLocator()
days=mdates.DayLocator()
timeFmt=mdates.DateFormatter('%Y-%m')
events=[datetime.date(2015,1,23),datetime.date(2015,1,28),datetime.date(2015,2,3),datetime.date(2015,2,21),datetime.date(2015,3,15)
       ,datetime.date(2015,3,24),datetime.date(2015,4,8),datetime.date(2015,4,24)]
readings=[12,22,25,20,18,15,17,14]
fig,ax=plt.subplots()
plt.plot(events,readings)
ax.xaxis.set_major_locator(months)
ax.xaxis.set_major_formatter(timeFmt)
ax.xaxis.set_minor_locator(days)

# %%
plt.show()

# %%
x=np.arange(-2*np.pi,2*np.pi,0.01)
#y=np.sin(5*x)/x
y1=np.sin(2*x)/x
y2=np.sin(3*x)/x
y3=np.sin(4*x)/x
#plt.plot(x,y1,'k--',linewidth=3)
#plt.plot(x,y2,'m-.')
#plt.plot(x,y3,color='#87a3cc',linestyle='--')
plt.plot(x,y1,color='b')
plt.plot(x,y2,color='r')
plt.plot(x,y3,color='g')
#zhi ding ge shi 
plt.xticks([-2*np.pi,-np.pi,0,np.pi,2*np.pi],[r'$-2\pi$',r'$-\pi$',r'$0$',r'$+\pi$',r'$+2\pi$'])

plt.show()

# %%
x=np.arange(-2*np.pi,2*np.pi,0.01)

y1=np.sin(2*x)/x
y2=np.sin(3*x)/x
y3=np.sin(4*x)/x

plt.plot(x,y1,color='b')
plt.plot(x,y2,color='r')
plt.plot(x,y3,color='g')

plt.xticks([-2*np.pi,-np.pi,0,np.pi,2*np.pi],[r'$-2\pi$',r'$-\pi$',r'$0$',r'$+\pi$',r'$+2\pi$'])

ax=plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')#xia
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')#zuo
ax.spines['left'].set_position(('data',0))
plt.show()

# %%
x=np.arange(-2*np.pi,2*np.pi,0.01)

y1=np.sin(2*x)/x
y2=np.sin(3*x)/x
y3=np.sin(4*x)/x

plt.plot(x,y1,color='b')
plt.plot(x,y2,color='r')
plt.plot(x,y3,color='g')

plt.xticks([-2*np.pi,-np.pi,0,np.pi,2*np.pi],[r'$-2\pi$',r'$-\pi$',r'$0$',r'$+\pi$',r'$+2\pi$'])

plt.annotate(r'$lim_{x\to 0}\frac{sin(x)}{x}=1$',xy=[0,1],xycoords='data',xytext=[30,30],fontsize=16,textcoords='offset points',
                    arrowprops=dict(arrowstyle='->',connectionstyle='arc3,rad=.2'))

ax=plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')#xia
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')#zuo
ax.spines['left'].set_position(('data',0))
plt.show()

# %%
from pandas import DataFrame,Series
import pandas as pd

# %%
data={'series1':[1,3,4,3,5],
           'series2':[2,4,5,2,4],
            'series3':[3,2,3,1,3]}
df=pd.DataFrame(data)
x=np.arange(5)
plt.axis([0,5,0,7])
plt.plot(x,df)
plt.legend(data,loc=2)
plt.show()

# %%
 pop=np.random.randint(0,100,100)

# %%
pop
# Out:
# array([23, 81, 57, 35, 61, 19,  3, 41, 48, 68, 10, 70, 59,  3, 78, 23, 41,
#        62, 52, 85, 98, 71, 68, 50, 15, 46,  3, 35, 78,  7, 70, 11, 98, 82,
#        55, 72,  2, 55, 84, 99, 17,  6, 71, 52, 52, 58, 92, 17, 54, 75, 19,
#        60, 47,  3, 69, 85, 87, 70, 91, 52,  7,  5, 28, 18, 58, 32, 57, 32,
#        87, 90, 29, 48, 14, 99, 47, 69, 59, 49, 57, 81, 80,  0, 91, 87,  7,
#        26, 73, 75,  3, 17, 51, 34, 48, 60, 78, 65,  4, 57, 14, 29])

# %%
n,bins,patches=plt.hist(pop,bins=20)
plt.show()

# %%
index=np.arange(5)
values=[5,7,3,4,6]
plt.bar(index,values)
plt.xticks(index+0.4,['A','B','C','D','E'])
plt.show()

# %%
index=np.arange(5)
values=[5,7,3,4,6]
std1=[0.8,1.0,0.4,0.9,1.3]

plt.title("A Bar Chart")
plt.barh(index,values,xerr=std1,error_kw={'ecolor':'0.1','capsize':6},alpha=0.7,label="First")
plt.yticks(index+0.4,['A','B','C','D','E'])
plt.legend(loc=5)
plt.show()

# %%
index=np.arange(5)
v1=[5,7,2,4,6]
v2=[6,6,4,5,7]
v3=[5,6,5,4,6]
bw=0.1
#plt.axis([0,5,0,8])
plt.title('A AAAAAAAAAAAAAAAA')
plt.barh(index,v1,bw,color='b')
plt.barh(index+bw,v2,bw,color='g')
plt.barh(index+2*bw,v3,bw,color='r')

plt.yticks(index+1.5*bw,['A','B','C','D','E'])
plt.show()

# %%
data={'series1':[1,3,4,3,5],
           'series2':[2,4,5,2,4],
            'series3':[3,2,3,1,3]}
df=pd.DataFrame(data)
df.plot(kind='bar')
plt.show()

# %%
s1=np.array([3,4,5,3])
s2=np.array([1,2,2,5])
s3=np.array([2,3,3,4])
index=np.arange(4)
#plt.axis([0,4,0,15])
plt.barh(index,s1,color='r')
plt.barh(index,s2,color='b',left=s1)#bottom=s1)
plt.barh(index,s3,color='g',left=s1+s2)#bottom=s1+s2)
plt.yticks(index+0.4,['Jan15','Feb15','Mar15','Apr15'])
plt.show()

# %%
s1=np.array([3,4,5,3])
s2=np.array([1,2,2,5])
s3=np.array([2,3,3,4])
index=np.arange(4)
#plt.axis([0,4,0,15])
plt.barh(index,s1,color='r',hatch='xx')
plt.barh(index,s2,color='b',left=s1,hatch='.')#bottom=s1)
plt.barh(index,s3,color='g',left=s1+s2,hatch='./')#bottom=s1+s2)
plt.yticks(index+0.4,['Jan15','Feb15','Mar15','Apr15'])
plt.show()

# %%
data={'series1':[1,3,4,3,5],
           'series2':[2,4,5,2,4],
            'series3':[3,2,3,1,3]}
df=pd.DataFrame(data)
df.plot(kind='barh',stacked=True)
#plt.legend(loc=5)
plt.show()

# %%
x0=np.arange(8)
y1=np.array([1,3,4,6,4,3,2,1])
y2=np.array([1,2,5,4,3,3,2,1])
plt.ylim(-8,8)
plt.bar(x0,y1,0.9,facecolor='r',edgecolor='w')
plt.bar(x0,-y2,0.9,facecolor='b',edgecolor='w')
plt.xticks(())
plt.grid(True)
for x, y in zip(x0,y1):
    plt.text(x+0.4,y+0.05,'%d'% y ,ha='center',va='bottom')
for x,y in zip(x0,y2):
    plt.text(x+0.4,-y-0.05,'%d' % y,ha='center',va='top')
    
plt.show()

# %%
label=['Nokia','Samsung','Apple','Lumia']
values=[10,30,45,15]
colors=['yellow','green','red','blue']
plt.pie(values,labels=label,colors=colors)
#plt.axis('equal')
plt.show()

# %%
label=['Nokia','Samsung','Apple','Lumia']
values=[10,30,45,15]
colors=['yellow','green','red','blue']
plt.pie(values,labels=label,colors=colors)
#plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-277-f3cf8f8eb46e> in <module>()
# ----> 1 type()
#
# TypeError: type() takes 1 or 3 arguments

# %%
label=['Nokia','Samsung','Apple','Lumia']
values=[10,30,45,15]
colors=['yellow','green','red','blue']
explode=[0.3,0,0,0]
plt.title("A-AAA")
plt.pie(values,labels=label,colors=colors,explode=explode,shadow=True,autopct='%1.1f%%',startangle=180)
#plt.axis('equal')
plt.show()

# %%
data={'series1':[1,3,4,3,5],
           'series2':[2,4,5,2,4],
            'series3':[3,2,3,1,3]}
df=pd.DataFrame(data)
colors=['yellow','green','red','blue','w']
explode=[0.3,0,0,0,0]
df['series1'].plot(kind='pie',figsize=(6,6),colors=colors,explode=explode,shadow=True,autopct='%1.1f%%',startangle=180)
plt.show()

# %%
dx=0.01;dy=0.01
x=np.arange(-2.0,2.0,dx)
y=np.arange(-2.0,2.0,dy)
x,y=np.meshgrid(x,y)

# %%
def f(x,y):
    return(1-y**5+x**5)*np.exp(-x**2-y**2)

# %%
C=plt.contour(x,y,f(x,y),8,colors='black')
plt.contourf(x,y,f(x,y),8)
plt.clabel(C,inline=1,fontsize=10)
plt.show()

# %%
C=plt.contour(x,y,f(x,y),8,colors='black')
plt.contourf(x,y,f(x,y),8)#,cmap=plt.cm.hot)
plt.clabel(C,inline=1,fontsize=10)
plt.colorbar()
plt.show()

# %%
N=8
theta=np.arange(0.,2*np.pi,2*np.pi/N)
radii=np.array([4,7,5,3,5,6,7,3])
plt.axes([0.025,0.025,0.95,0.95],polar=True)
colors=np.array(['#4bb2c5','#c5b47f','#EAA228','#579575','#830577','#958c12','#953579','#4b5de4'])
bars=plt.bar(theta,radii,width=(2*np.pi/N),bottom=0.,color=colors)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig=plt.figure()
ax=Axes3D(fig)
X=np.arange(-2,2,0.1)
Y=np.arange(-2,2,0.1)
X,Y=np.meshgrid(X,Y)

# %%
def f(x,y):
    return (1-y**5+x**5)*np.exp(-x**2-y**2)

# %%
ax.plot_surface(X,Y,f(X,Y),rstride=1,cstride=2)
plt.show()

# %%
ax.plot_surface(X,Y,f(X,Y),rstride=1,cstride=1,cmap=plt.cm.hot)
ax.view_init(elev=30,azim=125)
plt.show()

# %%
xs=np.random.randint(30,40,100)
ys=np.random.randint(20,30,100)
zs=np.random.randint(10,20,100)

xs2=np.random.randint(50,60,100)
ys2=np.random.randint(30,40,100)
zs2=np.random.randint(50,70,100)

xs3=np.random.randint(10,40,100)
ys3=np.random.randint(40,50,100)
zs3=np.random.randint(40,50,100)

fig=plt.figure()
ax=Axes3D(fig)
ax.scatter(xs,ys,zs)
ax.scatter(xs2,ys2,zs2,c='r',marker='^')
ax.scatter(xs3,ys3,zs3,c='g',marker='*')
ax.set_xlabel("X Label")
ax.set_ylabel("Y Label")
ax.set_zlabel("Z Label")
plt.show()

# %%
x=np.arange(8)
y=np.random.randint(0,10,8)
y2=y+np.random.randint(0,3,8)
y3=y2+np.random.randint(0,3,8)
y4=y3+np.random.randint(0,3,8)
y5=y4+np.random.randint(0,3,8)

clr=['#4bb2c5','#c5b47f','#EAA228','#579575','#830577','#958c12','#953579','#4b5de4']
fig=plt.figure()
ax=Axes3D(fig)
ax.bar(x,y,0,zdir='y',color=clr)
ax.bar(x,y2,10,zdir='y',color=clr)
ax.bar(x,y3,20,zdir='y',color=clr)
ax.bar(x,y4,30,zdir='y',color=clr)
ax.bar(x,y5,40,zdir='y',color=clr)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.view_init(elev=40)
plt.show()

# %%
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,0.8,0.8])
inner_ax=fig.add_axes([0.6,0.6,0.25,0.25])

plt.show()

# %%
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,0.8,0.8])
inner_ax=fig.add_axes([0.6,0.6,0.25,0.25])
x1=np.arange(10)
y1=np.array([1,2,7,1,5,2,4,2,3,1])
x2=np.arange(10)
y2=np.array([1,3,4,5,4,5,2,6,4,3])
ax.plot(x1,y1)
inner_ax.plot(x2,y2)
plt.show()

# %%
gs=plt.GridSpec(3,3)
fig=plt.figure()
fig.add_subplot(gs[1,:2])
fig.add_subplot(gs[0,:2])
fig.add_subplot(gs[2,0])
fig.add_subplot(gs[:2,2])
fig.add_subplot(gs[2,1:])
plt.show()

# %%
gs=plt.GridSpec(3,3)
fig=plt.figure()
x1=np.array([1,3,2,5])
y1=np.array([4,3,7,2])
x2=np.arange(5)
y2=np.array([3,2,4,6,4])

s1=fig.add_subplot(gs[1,:2])
s1.plot(x,y,'r')

s2=fig.add_subplot(gs[0,:2])
s2.bar(x2,y2)

s3=fig.add_subplot(gs[2,0])
s3.barh(x2,y2,color='g')

s4=fig.add_subplot(gs[:2,2])
s4.plot(x2,y2,'k')

s5=fig.add_subplot(gs[2,1:])
s5.plot(x1,y1,'b^',x2,y2,'yo')
plt.show()
fig.add_subplot(gs[0,:2])
fig.add_subplot(gs[2,0])
fig.add_subplot(gs[:2,2])
fig.add_subplot(gs[2,1:])
plt.show()
